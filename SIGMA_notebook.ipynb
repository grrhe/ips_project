# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
from time import sleep
from custom_module import get_tickers, parse_yf_esg, parse_mc
from settings import TOTALLY_NOT_A_PARSER
from tqdm import tqdm

# %% [markdown]
# Идеи:
# 1. Взять ESG с Yahoo finance

# %%
main_df = pd.DataFrame(columns=['Date', 'Name', 'Average stock price', 'Revenue', 'Assets', 'Glassdoor rating'])

# %%
main_df
# Out:
# Empty DataFrame
# Columns: [Date, Name, Average stock price, Revenue, Assets, Glassdoor rating]
# Index: []

# %%
esg_score = parse_yf_esg()

print(esg_score)
# Out:
# 100%|██████████| 7554/7554 [12:35:59<00:00,  6.00s/it]
# ...

# %%
df_pars = pd.DataFrame(esg_score, index=get_tickers()[0:-1])
df_pars
# Out:
#         Environment Risk Score  Social Risk Score  Governance Risk Score
# Symbol
# A                          0.3                8.6                    0.3
# AA                        14.3                5.9                   14.3
# AAC                        NaN                NaN                    NaN
# AACG                       NaN                NaN                    NaN
# AACI                       NaN                NaN                    NaN
# ...                        ...                ...                    ...
# ZVRA                       NaN                NaN                    NaN
# ZVSA                       NaN                NaN                    NaN
# ZWS                        NaN                NaN                    NaN
# ZYME                       NaN                NaN                    NaN
# ZYNE                       NaN                NaN                    NaN
#
# [7554 rows x 3 columns]

# %%
df = get_tickers()
df.count()
# Out:
# 7555

# %%
a = 'dfsd'
a[0:-1]
# Out:
# 'dfs'

# %%
# df_pars.to_csv('esg.csv')

# %%
df_pars.notna().sum()
# Out:
# Environment Risk Score    781
# Social Risk Score         781
# Governance Risk Score     781
# dtype: int64

# %%
df_pars_notna = df_pars[df_pars['Environment Risk Score'].notna()]
# df_pars_notna.to_csv('true_esg.csv')

# %%
tickers = pd.read_csv('true_esg.csv')['Symbol']

pars = parse_mc(tickers)
print(pars)
# Out:
# 100%|██████████| 781/781 [06:14<00:00,  2.09it/s]
# ...

# %%
pd.read_csv('true_esg.csv')['Symbol'][364]
# Out:
# 'HST'

# %%
print(pars)
a = pd.DataFrame(pars[0])
a.to_csv('financials.csv')
# Out:
# ({'Компания': ['A', 'AA', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABT', 'ACGL', 'ACM', 'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'ADX', 'AEE', 'AEF', 'AEM', 'AEP', 'AER', 'AES', 'AFG', 'AFL', 'AGD', 'AGNC', 'AIG', 'AIV', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALKS', 'ALL', 'ALLE', 'ALLY', 'ALV', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'ANET', 'ANSS', 'AOD', 'AOS', 'APA', 'APD', 'APH', 'APTV', 'AR', 'ARE', 'ARMK', 'ARW', 'ASG', 'ASH', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVK', 'AVT', 'AVY', 'AWK', 'AWP', 'AXP', 'AXS', 'AXTA', 'AYI', 'AZO', 'BA', 'BAC', 'BAH', 'BALL', 'BAM', 'BAP', 'BAX', 'BBWI', 'BBY', 'BCE', 'BCV', 'BDJ', 'BDX', 'BEN', 'BEP', 'BFH', 'BG', 'BGR', 'BGY', 'BHC', 'BIDU', 'BIIB', 'BIO', 'BK', 'BKNG', 'BLK', 'BME', 'BMO', 'BMRN', 'BMY', 'BNS', 'BOE', 'BOKF', 'BPYPP', 'BR', 'BRO', 'BRX', 'BST', 'BSX', 'BTO', 'BWA', 'BX', 'BXMX', 'BXP', 'C', 'CAF', 'CAG', 'CAH', 'CAT', 'CB', 'CBOE', 'CBRE', 'CBSH', 'CCD', 'CCI', 'CCK', 'CCL', 'CDNS', 'CDW', 'CE', 'CEE', 'CERS', 'CET', 'CF', 'CF
# ...

# %%
pd.DataFrame(parse_mc(pd.read_csv('true_esg.csv')['Symbol'][:10])[0])
# Out:
# 100%|██████████| 10/10 [00:03<00:00,  2.54it/s]
#   Компания  Чистая прибыль 2019  Чистая прибыль 2020  Чистая прибыль 2021  \
# 0        A         1.070000e+09         7.190000e+08         1.210000e+09
# 1       AA        -1.120000e+09        -1.700000e+08         4.290000e+08
# 2      AAL         1.690000e+09        -8.880000e+09        -1.990000e+09
# 3      AAP         4.870000e+08                  NaN         4.930000e+08
# 4     AAPL         5.530000e+10         5.740000e+10         9.470000e+10
# 5     ABBV         7.880000e+09         4.620000e+09         1.150000e+10
# 6      ABC         8.550000e+08        -3.410000e+09         1.540000e+09
# 7      ABT         3.690000e+09         4.500000e+09         7.070000e+09
# 8     ACGL         1.640000e+09         1.410000e+09         2.160000e+09
# 9      ACM        -2.610000e+08        -1.860000e+08         1.730000e+08
#
#    Капитализация 2019  Капитализация 2020  Капитализация 2021
# ...
